# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from xgboost.sklearn import xgboost_model_doc

# %%
train_data = pd.read_csv('data\\train.csv')
sub = pd.read_csv('data\\sample_submission.csv')

# %% [markdown]
# #### 1. Training dataset creation and feature engineering

# %% [markdown]
# ```order_number``` - order counter for each user<br>
# ```user_id``` - user ID<br>
# ```category``` - category<br>
# ```ordered```  - purchase counter for each category for each user<br>
# ```orders_total``` - total purchase counter for each user<br>
# ```rating``` - average amount of each category in  customer's purchase<br>
# ```total_ordered``` - purchase counter by all users<br>
# ```id``` - user_id / category as in submission file<br>
# ```target``` - target variable (the last known purchase)<br>

# %%
# sparse matrix for temporary use
train_raw = pd.get_dummies(train_data, columns=['cart'], prefix='', prefix_sep='', dtype='bool')
train_raw = train_raw.groupby(['user_id', 'order_completed_at']).any().reset_index()

# order counter for each use
train_raw['order_number'] = train_raw.groupby(['user_id']).cumcount()
train_raw = train_raw.drop('order_completed_at', axis=1)

# separate datasets by the last purchase
last_order = train_raw.groupby(['user_id'])['order_number'].transform(max) == train_raw['order_number']
train = train_raw[~last_order].groupby('user_id').sum().reset_index()
valid = train_raw[last_order].reset_index(drop=True)

#purchase counter for each category for each user
train_melt = pd.melt(train, id_vars=['user_id'], var_name='category', value_name='ordered')
valid_melt = pd.melt(valid, id_vars=['user_id'], var_name='category', value_name='target')

Train = train_melt.copy()

# total purchase counter for each user
order_number = valid[['user_id', 'order_number']].set_index('user_id').squeeze()
Train['orders_total'] = Train['user_id'].map(order_number)

#average amount of each category in  customer's purchase
Train['rating'] = Train['ordered'] / Train['orders_total']

# user_id / category as in submission file
Train['id'] = Train['user_id'].astype(str) + ';' + Train['category']

# target variable (the last known purchase)
Train['target'] = valid_melt['target'].astype(int)

#remove those users/categories who are not represented in the submission file
Train = Train[Train.id.isin(sub.id.unique())].reset_index(drop=True)
#Check
print((Train.sort_values('id')['id'].values == Train.sort_values('id')['id'].values).all())

#purchase counter by all user (for represetned users)
total_ordered = Train.groupby('category')['ordered'].sum()
Train['total_ordered'] = Train['category'].map(total_ordered)

Train.head(3)
# Out:
# True
#    user_id category  ordered  orders_total    rating   id  target  \
# 0        7        0        0            10  0.000000  7;0       1
# 1        8        0        1             7  0.142857  8;0       0
# 2        9        0        1            45  0.022222  9;0       0
#
#    total_ordered
# 0          12922
# 1          12922
# 2          12922

# %%
Train_set, Valid_set = train_test_split(Train, test_size=0.2,
                                        stratify=None, random_state=17)

# %% [markdown]
# #### 2. Model training

# %% [markdown]
# Kfold catboost

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold

# %%
def f1(real, pred, **kwargs):
    return f1_score(real, (pred > 0.5).astype(int), **kwargs)

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
y = Train.target
X = Train.drop(columns=["user_id", "id", "target"])

models = []
for train_index, val_index in skf.split(X, y):
    X_train, X_valid = X.iloc[train_index], X.iloc[val_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[val_index]

    model = CatBoostClassifier(
        iterations=5000,
        depth=10,
        l2_leaf_reg=3,
        eval_metric="F1",  # Оценка по F1
        random_seed=42,
        verbose=100,
        early_stopping_rounds=700,
        use_best_model=True,
        task_type="GPU",
        devices='0',
        auto_class_weights="SqrtBalanced"
    )
    model.fit(X_train, y_train, eval_set=(X_valid, y_valid))
    models.append(model)
# Out:
# 0:	learn: 0.6538521	test: 0.6558371	best: 0.6558371 (0)	total: 21.4ms	remaining: 1m 46s
# 100:	learn: 0.6607682	test: 0.6625889	best: 0.6630456 (86)	total: 1.89s	remaining: 1m 31s
# 200:	learn: 0.6621224	test: 0.6639733	best: 0.6642232 (189)	total: 3.74s	remaining: 1m 29s
# 300:	learn: 0.6628657	test: 0.6637147	best: 0.6642232 (189)	total: 5.61s	remaining: 1m 27s
# 400:	learn: 0.6639919	test: 0.6638219	best: 0.6642232 (189)	total: 7.46s	remaining: 1m 25s
# 500:	learn: 0.6656825	test: 0.6641342	best: 0.6645065 (483)	total: 9.33s	remaining: 1m 23s
# 600:	learn: 0.6668648	test: 0.6648419	best: 0.6648419 (600)	total: 11.2s	remaining: 1m 21s
# 700:	learn: 0.6675816	test: 0.6648646	best: 0.6650261 (655)	total: 13s	remaining: 1m 19s
# 800:	learn: 0.6682324	test: 0.6643938	best: 0.6650261 (655)	total: 14.9s	remaining: 1m 17s
# 900:	learn: 0.6688224	test: 0.6643131	best: 0.6650261 (655)	total: 16.7s	remaining: 1m 16s
# 1000:	learn: 0.6692991	test: 0.6646138	best: 0.6650261 (655)	total: 18.6s	remaining: 1m 14s
# 1100:	learn: 0.6700291	test: 0.6644741	best: 0.6650261 (655)	total: 20.5s	remaining: 1m 12s
# 1200:	learn: 0.6706780	test: 0.6641872	best: 0.6650261 (655)	total: 22.3s	remaining: 1m 10s
# 1300:	learn: 0.6710148	test: 0.6639350	best: 0.6650261 (655)	total: 24.1s	remaining: 1m 8s
# bestTest = 0.6650261155
# bestIteration = 655
# Shrink model to first 656 iterations.
# 0:	learn: 0.6558624	test: 0.6550389	best: 0.6550389 (0)	total: 18.1ms	remaining: 1m 30s
# 100:	learn: 0.6615283	test: 0.6600075	best: 0.6600428 (17)	total: 1.84s	remaining: 1m 29s
# 200:	learn: 0.6629777	test: 0.6607260	best: 0.6607844 (197)	total: 3.72s	remaining: 1m 28s
# 300:	learn: 0.6647571	test: 0.6616687	best: 0.6616942 (231)	total: 5.61s	remaining: 1m 27s
# 400:	learn: 0.6655929	test: 0.6621544	best: 0.6622956 (337)	total: 7.41s	remaining: 1m 24s
# 500:	learn: 0.6665882	test: 0.6623124	best: 0.6626633 (462)	total: 9.33s	remaining: 1m 23s
# 600:	learn: 0.6674777	test: 0.6626116	best: 0.6627179 (597)	total: 11.1s	remaining: 1m 21s
# 700:	learn: 0.6681784	test: 0.6622956	best: 0.6627179 (597)	total: 13s	remaining: 1m 19s
# 800:	learn: 0.6691403	test: 0.6619917	best: 0.6627179 (597)	total: 14.8s	remaining: 1m 17s
# 900:	learn: 0.6702630	test: 0.6625722	best: 0.6627179 (597)	total: 16.7s	remaining: 1m 16s
# 1000:	learn: 0.6708539	test: 0.6621793	best: 0.6627179 (597)	total: 18.6s	remaining: 1m 14s
# 1100:	learn: 0.6714078	test: 0.6618636	best: 0.6627179 (597)	total: 20.4s	remaining: 1m 12s
# 1200:	learn: 0.6720253	test: 0.6616969	best: 0.6627179 (597)	total: 22.2s	remaining: 1m 10s
# bestTest = 0.6627179477
# bestIteration = 597
# Shrink model to first 598 iterations.
# 0:	learn: 0.6549670	test: 0.6512067	best: 0.6512067 (0)	total: 18.1ms	remaining: 1m 30s
# 100:	learn: 0.6617515	test: 0.6578964	best: 0.6579460 (89)	total: 1.81s	remaining: 1m 28s
# 200:	learn: 0.6638963	test: 0.6594501	best: 0.6594730 (198)	total: 3.67s	remaining: 1m 27s
# 300:	learn: 0.6647524	test: 0.6598613	best: 0.6599998 (290)	total: 5.45s	remaining: 1m 25s
# 400:	learn: 0.6659952	test: 0.6599039	best: 0.6599998 (290)	total: 7.28s	remaining: 1m 23s
# 500:	learn: 0.6670817	test: 0.6603594	best: 0.6604094 (463)	total: 9.13s	remaining: 1m 22s
# 600:	learn: 0.6679125	test: 0.6606061	best: 0.6607558 (537)	total: 11s	remaining: 1m 20s
# 700:	learn: 0.6686228	test: 0.6604637	best: 0.6607558 (537)	total: 12.8s	remaining: 1m 18s
# 800:	learn: 0.6692619	test: 0.6606455	best: 0.6607558 (537)	total: 14.7s	remaining: 1m 16s
# 900:	learn: 0.6699802	test: 0.6608368	best: 0.6609962 (883)	total: 16.6s	remaining: 1m 15s
# 1000:	learn: 0.6707073	test: 0.6606232	best: 0.6609962 (883)	total: 18.5s	remaining: 1m 13s
# 1100:	learn: 0.6714220	test: 0.6606401	best: 0.6609962 (883)	total: 20.3s	remaining: 1m 11s
# 1200:	learn: 0.6720929	test: 0.6603994	best: 0.6609962 (883)	total: 22.1s	remaining: 1m 10s
# 1300:	learn: 0.6731584	test: 0.6603712	best: 0.6609962 (883)	total: 23.9s	remaining: 1m 8s
# 1400:	learn: 0.6734887	test: 0.6603089	best: 0.6609962 (883)	total: 25.8s	remaining: 1m 6s
# 1500:	learn: 0.6740710	test: 0.6604417	best: 0.6609962 (883)	total: 27.6s	remaining: 1m 4s
# bestTest = 0.6609962045
# bestIteration = 883
# Shrink model to first 884 iterations.
# 0:	learn: 0.6548254	test: 0.6591774	best: 0.6591774 (0)	total: 18.9ms	remaining: 1m 34s
# 100:	learn: 0.6589803	test: 0.6632024	best: 0.6633424 (97)	total: 1.86s	remaining: 1m 30s
# 200:	learn: 0.6615104	test: 0.6647405	best: 0.6647973 (199)	total: 3.71s	remaining: 1m 28s
# 300:	learn: 0.6631209	test: 0.6657168	best: 0.6657364 (287)	total: 5.54s	remaining: 1m 26s
# 400:	learn: 0.6640455	test: 0.6655147	best: 0.6657364 (287)	total: 7.39s	remaining: 1m 24s
# 500:	learn: 0.6645695	test: 0.6649443	best: 0.6657364 (287)	total: 9.26s	remaining: 1m 23s
# 600:	learn: 0.6656329	test: 0.6650794	best: 0.6657364 (287)	total: 11.2s	remaining: 1m 21s
# 700:	learn: 0.6662707	test: 0.6649762	best: 0.6657364 (287)	total: 13.1s	remaining: 1m 20s
# 800:	learn: 0.6669398	test: 0.6646026	best: 0.6657364 (287)	total: 14.9s	remaining: 1m 18s
# 900:	learn: 0.6672501	test: 0.6643030	best: 0.6657364 (287)	total: 16.7s	remaining: 1m 16s
# bestTest = 0.6657363799
# bestIteration = 287
# Shrink model to first 288 iterations.
# 0:	learn: 0.6561745	test: 0.6537603	best: 0.6537603 (0)	total: 19ms	remaining: 1m 35s
# 100:	learn: 0.6606156	test: 0.6585659	best: 0.6586291 (7)	total: 1.87s	remaining: 1m 30s
# 200:	learn: 0.6630350	test: 0.6590425	best: 0.6595226 (182)	total: 3.71s	remaining: 1m 28s
# 300:	learn: 0.6640562	test: 0.6590710	best: 0.6595226 (182)	total: 5.55s	remaining: 1m 26s
# 400:	learn: 0.6651014	test: 0.6589547	best: 0.6595226 (182)	total: 7.41s	remaining: 1m 25s
# 500:	learn: 0.6658028	test: 0.6589832	best: 0.6595226 (182)	total: 9.27s	remaining: 1m 23s
# 600:	learn: 0.6667009	test: 0.6589603	best: 0.6595226 (182)	total: 11.1s	remaining: 1m 21s
# 700:	learn: 0.6675117	test: 0.6589602	best: 0.6595226 (182)	total: 13s	remaining: 1m 19s
# 800:	learn: 0.6688651	test: 0.6595801	best: 0.6595801 (799)	total: 14.8s	remaining: 1m 17s
# 900:	learn: 0.6697915	test: 0.6600163	best: 0.6600827 (895)	total: 16.7s	remaining: 1m 16s
# 1000:	learn: 0.6704318	test: 0.6598191	best: 0.6601223 (908)	total: 18.6s	remaining: 1m 14s
# 1100:	learn: 0.6711210	test: 0.6597083	best: 0.6601223 (908)	total: 20.4s	remaining: 1m 12s
# 1200:	learn: 0.6720208	test: 0.6596543	best: 0.6601223 (908)	total: 22.2s	remaining: 1m 10s
# 1300:	learn: 0.6726765	test: 0.6596995	best: 0.6601223 (908)	total: 24s	remaining: 1m 8s
# 1400:	learn: 0.6732475	test: 0.6597978	best: 0.6601223 (908)	total: 25.7s	remaining: 1m 6s
# 1500:	learn: 0.6737096	test: 0.6598246	best: 0.6601223 (908)	total: 27.5s	remaining: 1m 4s
# 1600:	learn: 0.6741747	test: 0.6598325	best: 0.6601223 (908)	total: 29.3s	remaining: 1m 2s
# bestTest = 0.6601222665
# bestIteration = 908
# Shrink model to first 909 iterations.

# %% [markdown]
# xgboost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold

# %%
def f1(real, pred, **kwargs):
    return 'custom_f1', f1_score(real, (pred > 0.5).astype(int), **kwargs)


skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
y = Train.target
X = Train.drop(columns=["user_id", "id", "target"])

# %%
X
# Out:
#        category  ordered  orders_total    rating  total_ordered
# 0             0        0            10  0.000000          12922
# 1             0        1             7  0.142857          12922
# 2             0        1            45  0.022222          12922
# 3             0        1            20  0.050000          12922
# 4             0        3            16  0.187500          12922
# ...         ...      ...           ...       ...            ...
# 790444      880        2            70  0.028571              7
# 790445      880        1            22  0.045455              7
# 790446      880        2             8  0.250000              7
# 790447      880        1             3  0.333333              7
# 790448      880        1             4  0.250000              7
#
# [790449 rows x 5 columns]

# %%
X["category"] = X["category"].astype("category")
X["category"]
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 790444    880
# 790445    880
# 790446    880
# 790447    880
# 790448    880
# Name: category, Length: 790449, dtype: category
# Categories (858, object): ['0', '1', '10', '100', ..., '96', '97', '98', '99']

# %%
models_xgb = []
for train_index, val_index in skf.split(X, y):
    X_train, X_valid = X.iloc[train_index], X.iloc[val_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[val_index]

    model = XGBClassifier(
        reg_lambda=12,
        enable_categorical=True,
        early_stopping_rounds=700,
    )
    model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
    models_xgb.append(model)
# Out:
# [0]	validation_0-logloss:0.46042
# [1]	validation_0-logloss:0.42331
# [2]	validation_0-logloss:0.40167
# [3]	validation_0-logloss:0.38831
# [4]	validation_0-logloss:0.37978
# [5]	validation_0-logloss:0.37419
# [6]	validation_0-logloss:0.37047
# [7]	validation_0-logloss:0.36806
# [8]	validation_0-logloss:0.36641
# [9]	validation_0-logloss:0.36529
# [10]	validation_0-logloss:0.36455
# [11]	validation_0-logloss:0.36405
# [12]	validation_0-logloss:0.36371
# [13]	validation_0-logloss:0.36346
# [14]	validation_0-logloss:0.36330
# [15]	validation_0-logloss:0.36319
# [16]	validation_0-logloss:0.36310
# [17]	validation_0-logloss:0.36305
# [18]	validation_0-logloss:0.36301
# [19]	validation_0-logloss:0.36300
# [20]	validation_0-logloss:0.36295
# [21]	validation_0-logloss:0.36296
# [22]	validation_0-logloss:0.36294
# [23]	validation_0-logloss:0.36298
# [24]	validation_0-logloss:0.36296
# [25]	validation_0-logloss:0.36295
# [26]	validation_0-logloss:0.36294
# [27]	validation_0-logloss:0.36297
# [28]	validation_0-logloss:0.36300
# [29]	validation_0-logloss:0.36303
# [30]	validation_0-logloss:0.36306
# [31]	validation_0-logloss:0.36304
# [32]	validation_0-logloss:0.36305
# [33]	validation_0-logloss:0.36309
# [34]	validation_0-logloss:0.36313
# [35]	validation_0-logloss:0.36316
# [36]	validation_0-logloss:0.36316
# [37]	validation_0-logloss:0.36321
# [38]	validation_0-logloss:0.36323
# [39]	validation_0-logloss:0.36324
# [40]	validation_0-logloss:0.36327
# [41]	validation_0-logloss:0.36328
# [42]	validation_0-logloss:0.36331
# [43]	validation_0-logloss:0.36332
# [44]	validation_0-logloss:0.36333
# [45]	validation_0-logloss:0.36335
# [46]	validation_0-logloss:0.36336
# [47]	validation_0-logloss:0.36337
# [48]	validation_0-logloss:0.36339
# [49]	validation_0-logloss:0.36345
# [50]	validation_0-logloss:0.36347
# [51]	validation_0-logloss:0.36351
# [52]	validation_0-logloss:0.36355
# [53]	validation_0-logloss:0.36356
# [54]	validation_0-logloss:0.36355
# [55]	validation_0-logloss:0.36355
# [56]	validation_0-logloss:0.36358
# [57]	validation_0-logloss:0.36358
# [58]	validation_0-logloss:0.36359
# [59]	validation_0-logloss:0.36360
# [60]	validation_0-logloss:0.36360
# [61]	validation_0-logloss:0.36365
# [62]	validation_0-logloss:0.36365
# [63]	validation_0-logloss:0.36365
# [64]	validation_0-logloss:0.36365
# [65]	validation_0-logloss:0.36366
# [66]	validation_0-logloss:0.36370
# [67]	validation_0-logloss:0.36373
# [68]	validation_0-logloss:0.36374
# [69]	validation_0-logloss:0.36374
# [70]	validation_0-logloss:0.36376
# [71]	validation_0-logloss:0.36378
# [72]	validation_0-logloss:0.36379
# [73]	validation_0-logloss:0.36380
# [74]	validation_0-logloss:0.36380
# [75]	validation_0-logloss:0.36382
# [76]	validation_0-logloss:0.36385
# [77]	validation_0-logloss:0.36387
# [78]	validation_0-logloss:0.36390
# [79]	validation_0-logloss:0.36394
# [80]	validation_0-logloss:0.36394
# [81]	validation_0-logloss:0.36398
# [82]	validation_0-logloss:0.36402
# [83]	validation_0-logloss:0.36402
# [84]	validation_0-logloss:0.36405
# [85]	validation_0-logloss:0.36406
# [86]	validation_0-logloss:0.36407
# [87]	validation_0-logloss:0.36410
# [88]	validation_0-logloss:0.36412
# [89]	validation_0-logloss:0.36413
# [90]	validation_0-logloss:0.36413
# [91]	validation_0-logloss:0.36414
# [92]	validation_0-logloss:0.36416
# [93]	validation_0-logloss:0.36418
# [94]	validation_0-logloss:0.36421
# [95]	validation_0-logloss:0.36423
# [96]	validation_0-logloss:0.36424
# [97]	validation_0-logloss:0.36425
# [98]	validation_0-logloss:0.36425
# [99]	validation_0-logloss:0.36429
# [0]	validation_0-logloss:0.46073
# [1]	validation_0-logloss:0.42383
# [2]	validation_0-logloss:0.40235
# [3]	validation_0-logloss:0.38903
# [4]	validation_0-logloss:0.38050
# [5]	validation_0-logloss:0.37496
# [6]	validation_0-logloss:0.37124
# [7]	validation_0-logloss:0.36887
# [8]	validation_0-logloss:0.36729
# [9]	validation_0-logloss:0.36615
# [10]	validation_0-logloss:0.36542
# [11]	validation_0-logloss:0.36488
# [12]	validation_0-logloss:0.36455
# [13]	validation_0-logloss:0.36430
# [14]	validation_0-logloss:0.36410
# [15]	validation_0-logloss:0.36397
# [16]	validation_0-logloss:0.36388
# [17]	validation_0-logloss:0.36382
# [18]	validation_0-logloss:0.36377
# [19]	validation_0-logloss:0.36372
# [20]	validation_0-logloss:0.36373
# [21]	validation_0-logloss:0.36371
# [22]	validation_0-logloss:0.36369
# [23]	validation_0-logloss:0.36370
# [24]	validation_0-logloss:0.36368
# [25]	validation_0-logloss:0.36369
# [26]	validation_0-logloss:0.36372
# [27]	validation_0-logloss:0.36375
# [28]	validation_0-logloss:0.36377
# [29]	validation_0-logloss:0.36376
# [30]	validation_0-logloss:0.36378
# [31]	validation_0-logloss:0.36379
# [32]	validation_0-logloss:0.36379
# [33]	validation_0-logloss:0.36379
# [34]	validation_0-logloss:0.36382
# [35]	validation_0-logloss:0.36385
# [36]	validation_0-logloss:0.36388
# [37]	validation_0-logloss:0.36389
# [38]	validation_0-logloss:0.36393
# [39]	validation_0-logloss:0.36394
# [40]	validation_0-logloss:0.36398
# [41]	validation_0-logloss:0.36398
# [42]	validation_0-logloss:0.36400
# [43]	validation_0-logloss:0.36402
# [44]	validation_0-logloss:0.36402
# [45]	validation_0-logloss:0.36405
# [46]	validation_0-logloss:0.36407
# [47]	validation_0-logloss:0.36407
# [48]	validation_0-logloss:0.36408
# [49]	validation_0-logloss:0.36409
# [50]	validation_0-logloss:0.36409
# [51]	validation_0-logloss:0.36411
# [52]	validation_0-logloss:0.36411
# [53]	validation_0-logloss:0.36410
# [54]	validation_0-logloss:0.36411
# [55]	validation_0-logloss:0.36411
# [56]	validation_0-logloss:0.36414
# [57]	validation_0-logloss:0.36418
# [58]	validation_0-logloss:0.36423
# [59]	validation_0-logloss:0.36425
# [60]	validation_0-logloss:0.36425
# [61]	validation_0-logloss:0.36424
# [62]	validation_0-logloss:0.36425
# [63]	validation_0-logloss:0.36426
# [64]	validation_0-logloss:0.36427
# [65]	validation_0-logloss:0.36430
# [66]	validation_0-logloss:0.36432
# [67]	validation_0-logloss:0.36431
# [68]	validation_0-logloss:0.36433
# [69]	validation_0-logloss:0.36435
# [70]	validation_0-logloss:0.36436
# [71]	validation_0-logloss:0.36439
# [72]	validation_0-logloss:0.36440
# [73]	validation_0-logloss:0.36443
# [74]	validation_0-logloss:0.36448
# [75]	validation_0-logloss:0.36450
# [76]	validation_0-logloss:0.36453
# [77]	validation_0-logloss:0.36452
# [78]	validation_0-logloss:0.36459
# [79]	validation_0-logloss:0.36462
# [80]	validation_0-logloss:0.36464
# [81]	validation_0-logloss:0.36466
# [82]	validation_0-logloss:0.36472
# [83]	validation_0-logloss:0.36473
# [84]	validation_0-logloss:0.36475
# [85]	validation_0-logloss:0.36478
# [86]	validation_0-logloss:0.36481
# [87]	validation_0-logloss:0.36483
# [88]	validation_0-logloss:0.36489
# [89]	validation_0-logloss:0.36491
# [90]	validation_0-logloss:0.36492
# [91]	validation_0-logloss:0.36493
# [92]	validation_0-logloss:0.36495
# [93]	validation_0-logloss:0.36496
# [94]	validation_0-logloss:0.36502
# [95]	validation_0-logloss:0.36507
# [96]	validation_0-logloss:0.36509
# [97]	validation_0-logloss:0.36512
# [98]	validation_0-logloss:0.36515
# [99]	validation_0-logloss:0.36516
# [0]	validation_0-logloss:0.46106
# [1]	validation_0-logloss:0.42441
# [2]	validation_0-logloss:0.40311
# [3]	validation_0-logloss:0.38998
# [4]	validation_0-logloss:0.38155
# [5]	validation_0-logloss:0.37608
# [6]	validation_0-logloss:0.37244
# [7]	validation_0-logloss:0.37004
# [8]	validation_0-logloss:0.36847
# [9]	validation_0-logloss:0.36742
# [10]	validation_0-logloss:0.36667
# [11]	validation_0-logloss:0.36613
# [12]	validation_0-logloss:0.36579
# [13]	validation_0-logloss:0.36558
# [14]	validation_0-logloss:0.36541
# [15]	validation_0-logloss:0.36529
# [16]	validation_0-logloss:0.36521
# [17]	validation_0-logloss:0.36515
# [18]	validation_0-logloss:0.36508
# [19]	validation_0-logloss:0.36507
# [20]	validation_0-logloss:0.36504
# [21]	validation_0-logloss:0.36502
# [22]	validation_0-logloss:0.36503
# [23]	validation_0-logloss:0.36500
# [24]	validation_0-logloss:0.36502
# [25]	validation_0-logloss:0.36501
# [26]	validation_0-logloss:0.36503
# [27]	validation_0-logloss:0.36507
# [28]	validation_0-logloss:0.36510
# [29]	validation_0-logloss:0.36509
# [30]	validation_0-logloss:0.36513
# [31]	validation_0-logloss:0.36513
# [32]	validation_0-logloss:0.36514
# [33]	validation_0-logloss:0.36519
# [34]	validation_0-logloss:0.36519
# [35]	validation_0-logloss:0.36520
# [36]	validation_0-logloss:0.36522
# [37]	validation_0-logloss:0.36524
# [38]	validation_0-logloss:0.36527
# [39]	validation_0-logloss:0.36528
# [40]	validation_0-logloss:0.36534
# [41]	validation_0-logloss:0.36538
# [42]	validation_0-logloss:0.36541
# [43]	validation_0-logloss:0.36542
# [44]	validation_0-logloss:0.36542
# [45]	validation_0-logloss:0.36543
# [46]	validation_0-logloss:0.36543
# [47]	validation_0-logloss:0.36545
# [48]	validation_0-logloss:0.36546
# [49]	validation_0-logloss:0.36547
# [50]	validation_0-logloss:0.36547
# [51]	validation_0-logloss:0.36550
# [52]	validation_0-logloss:0.36551
# [53]	validation_0-logloss:0.36551
# [54]	validation_0-logloss:0.36554
# [55]	validation_0-logloss:0.36556
# [56]	validation_0-logloss:0.36556
# [57]	validation_0-logloss:0.36559
# [58]	validation_0-logloss:0.36559
# [59]	validation_0-logloss:0.36560
# [60]	validation_0-logloss:0.36568
# [61]	validation_0-logloss:0.36570
# [62]	validation_0-logloss:0.36574
# [63]	validation_0-logloss:0.36575
# [64]	validation_0-logloss:0.36578
# [65]	validation_0-logloss:0.36578
# [66]	validation_0-logloss:0.36578
# [67]	validation_0-logloss:0.36578
# [68]	validation_0-logloss:0.36579
# [69]	validation_0-logloss:0.36582
# [70]	validation_0-logloss:0.36585
# [71]	validation_0-logloss:0.36584
# [72]	validation_0-logloss:0.36587
# [73]	validation_0-logloss:0.36588
# [74]	validation_0-logloss:0.36591
# [75]	validation_0-logloss:0.36592
# [76]	validation_0-logloss:0.36593
# [77]	validation_0-logloss:0.36595
# [78]	validation_0-logloss:0.36596
# [79]	validation_0-logloss:0.36598
# [80]	validation_0-logloss:0.36600
# [81]	validation_0-logloss:0.36603
# [82]	validation_0-logloss:0.36604
# [83]	validation_0-logloss:0.36607
# [84]	validation_0-logloss:0.36606
# [85]	validation_0-logloss:0.36611
# [86]	validation_0-logloss:0.36612
# [87]	validation_0-logloss:0.36615
# [88]	validation_0-logloss:0.36620
# [89]	validation_0-logloss:0.36623
# [90]	validation_0-logloss:0.36625
# [91]	validation_0-logloss:0.36629
# [92]	validation_0-logloss:0.36631
# [93]	validation_0-logloss:0.36632
# [94]	validation_0-logloss:0.36633
# [95]	validation_0-logloss:0.36633
# [96]	validation_0-logloss:0.36633
# [97]	validation_0-logloss:0.36637
# [98]	validation_0-logloss:0.36640
# [99]	validation_0-logloss:0.36644
# [0]	validation_0-logloss:0.45990
# [1]	validation_0-logloss:0.42263
# [2]	validation_0-logloss:0.40081
# [3]	validation_0-logloss:0.38725
# [4]	validation_0-logloss:0.37852
# [5]	validation_0-logloss:0.37284
# [6]	validation_0-logloss:0.36902
# [7]	validation_0-logloss:0.36655
# [8]	validation_0-logloss:0.36489
# [9]	validation_0-logloss:0.36367
# [10]	validation_0-logloss:0.36287
# [11]	validation_0-logloss:0.36230
# [12]	validation_0-logloss:0.36195
# [13]	validation_0-logloss:0.36170
# [14]	validation_0-logloss:0.36149
# [15]	validation_0-logloss:0.36138
# [16]	validation_0-logloss:0.36126
# [17]	validation_0-logloss:0.36120
# [18]	validation_0-logloss:0.36115
# [19]	validation_0-logloss:0.36111
# [20]	validation_0-logloss:0.36109
# [21]	validation_0-logloss:0.36107
# [22]	validation_0-logloss:0.36106
# [23]	validation_0-logloss:0.36106
# [24]	validation_0-logloss:0.36108
# [25]	validation_0-logloss:0.36107
# [26]	validation_0-logloss:0.36110
# [27]	validation_0-logloss:0.36109
# [28]	validation_0-logloss:0.36112
# [29]	validation_0-logloss:0.36115
# [30]	validation_0-logloss:0.36114
# [31]	validation_0-logloss:0.36114
# [32]	validation_0-logloss:0.36118
# [33]	validation_0-logloss:0.36121
# [34]	validation_0-logloss:0.36123
# [35]	validation_0-logloss:0.36122
# [36]	validation_0-logloss:0.36125
# [37]	validation_0-logloss:0.36128
# [38]	validation_0-logloss:0.36130
# [39]	validation_0-logloss:0.36132
# [40]	validation_0-logloss:0.36132
# [41]	validation_0-logloss:0.36132
# [42]	validation_0-logloss:0.36134
# [43]	validation_0-logloss:0.36134
# [44]	validation_0-logloss:0.36135
# [45]	validation_0-logloss:0.36135
# [46]	validation_0-logloss:0.36137
# [47]	validation_0-logloss:0.36139
# [48]	validation_0-logloss:0.36139
# [49]	validation_0-logloss:0.36140
# [50]	validation_0-logloss:0.36144
# [51]	validation_0-logloss:0.36144
# [52]	validation_0-logloss:0.36144
# [53]	validation_0-logloss:0.36145
# [54]	validation_0-logloss:0.36146
# [55]	validation_0-logloss:0.36150
# [56]	validation_0-logloss:0.36154
# [57]	validation_0-logloss:0.36158
# [58]	validation_0-logloss:0.36165
# [59]	validation_0-logloss:0.36166
# [60]	validation_0-logloss:0.36168
# [61]	validation_0-logloss:0.36171
# [62]	validation_0-logloss:0.36171
# [63]	validation_0-logloss:0.36174
# [64]	validation_0-logloss:0.36177
# [65]	validation_0-logloss:0.36180
# [66]	validation_0-logloss:0.36180
# [67]	validation_0-logloss:0.36182
# [68]	validation_0-logloss:0.36183
# [69]	validation_0-logloss:0.36183
# [70]	validation_0-logloss:0.36183
# [71]	validation_0-logloss:0.36182
# [72]	validation_0-logloss:0.36182
# [73]	validation_0-logloss:0.36184
# [74]	validation_0-logloss:0.36184
# [75]	validation_0-logloss:0.36184
# [76]	validation_0-logloss:0.36189
# [77]	validation_0-logloss:0.36190
# [78]	validation_0-logloss:0.36191
# [79]	validation_0-logloss:0.36194
# [80]	validation_0-logloss:0.36196
# [81]	validation_0-logloss:0.36197
# [82]	validation_0-logloss:0.36200
# [83]	validation_0-logloss:0.36203
# [84]	validation_0-logloss:0.36203
# [85]	validation_0-logloss:0.36205
# [86]	validation_0-logloss:0.36208
# [87]	validation_0-logloss:0.36211
# [88]	validation_0-logloss:0.36212
# [89]	validation_0-logloss:0.36213
# [90]	validation_0-logloss:0.36214
# [91]	validation_0-logloss:0.36217
# [92]	validation_0-logloss:0.36221
# [93]	validation_0-logloss:0.36224
# [94]	validation_0-logloss:0.36226
# [95]	validation_0-logloss:0.36231
# [96]	validation_0-logloss:0.36231
# [97]	validation_0-logloss:0.36233
# [98]	validation_0-logloss:0.36236
# [99]	validation_0-logloss:0.36238
# [0]	validation_0-logloss:0.46132
# [1]	validation_0-logloss:0.42462
# [2]	validation_0-logloss:0.40328
# [3]	validation_0-logloss:0.38999
# [4]	validation_0-logloss:0.38161
# [5]	validation_0-logloss:0.37609
# [6]	validation_0-logloss:0.37247
# [7]	validation_0-logloss:0.37008
# [8]	validation_0-logloss:0.36841
# [9]	validation_0-logloss:0.36734
# [10]	validation_0-logloss:0.36664
# [11]	validation_0-logloss:0.36618
# [12]	validation_0-logloss:0.36581
# [13]	validation_0-logloss:0.36556
# [14]	validation_0-logloss:0.36540
# [15]	validation_0-logloss:0.36530
# [16]	validation_0-logloss:0.36519
# [17]	validation_0-logloss:0.36513
# [18]	validation_0-logloss:0.36511
# [19]	validation_0-logloss:0.36510
# [20]	validation_0-logloss:0.36510
# [21]	validation_0-logloss:0.36510
# [22]	validation_0-logloss:0.36512
# [23]	validation_0-logloss:0.36513
# [24]	validation_0-logloss:0.36515
# [25]	validation_0-logloss:0.36518
# [26]	validation_0-logloss:0.36520
# [27]	validation_0-logloss:0.36524
# [28]	validation_0-logloss:0.36525
# [29]	validation_0-logloss:0.36528
# [30]	validation_0-logloss:0.36531
# [31]	validation_0-logloss:0.36533
# [32]	validation_0-logloss:0.36535
# [33]	validation_0-logloss:0.36541
# [34]	validation_0-logloss:0.36542
# [35]	validation_0-logloss:0.36544
# [36]	validation_0-logloss:0.36544
# [37]	validation_0-logloss:0.36545
# [38]	validation_0-logloss:0.36548
# [39]	validation_0-logloss:0.36551
# [40]	validation_0-logloss:0.36551
# [41]	validation_0-logloss:0.36552
# [42]	validation_0-logloss:0.36553
# [43]	validation_0-logloss:0.36555
# [44]	validation_0-logloss:0.36557
# [45]	validation_0-logloss:0.36558
# [46]	validation_0-logloss:0.36558
# [47]	validation_0-logloss:0.36560
# [48]	validation_0-logloss:0.36561
# [49]	validation_0-logloss:0.36563
# [50]	validation_0-logloss:0.36566
# [51]	validation_0-logloss:0.36569
# [52]	validation_0-logloss:0.36574
# [53]	validation_0-logloss:0.36574
# [54]	validation_0-logloss:0.36575
# [55]	validation_0-logloss:0.36576
# [56]	validation_0-logloss:0.36576
# [57]	validation_0-logloss:0.36579
# [58]	validation_0-logloss:0.36581
# [59]	validation_0-logloss:0.36584
# [60]	validation_0-logloss:0.36584
# [61]	validation_0-logloss:0.36586
# [62]	validation_0-logloss:0.36585
# [63]	validation_0-logloss:0.36586
# [64]	validation_0-logloss:0.36589
# [65]	validation_0-logloss:0.36589
# [66]	validation_0-logloss:0.36595
# [67]	validation_0-logloss:0.36596
# [68]	validation_0-logloss:0.36598
# [69]	validation_0-logloss:0.36599
# [70]	validation_0-logloss:0.36601
# [71]	validation_0-logloss:0.36603
# [72]	validation_0-logloss:0.36603
# [73]	validation_0-logloss:0.36604
# [74]	validation_0-logloss:0.36605
# [75]	validation_0-logloss:0.36605
# [76]	validation_0-logloss:0.36606
# [77]	validation_0-logloss:0.36607
# [78]	validation_0-logloss:0.36608
# [79]	validation_0-logloss:0.36614
# [80]	validation_0-logloss:0.36615
# [81]	validation_0-logloss:0.36617
# [82]	validation_0-logloss:0.36620
# [83]	validation_0-logloss:0.36620
# [84]	validation_0-logloss:0.36622
# [85]	validation_0-logloss:0.36624
# [86]	validation_0-logloss:0.36626
# [87]	validation_0-logloss:0.36626
# [88]	validation_0-logloss:0.36628
# [89]	validation_0-logloss:0.36630
# [90]	validation_0-logloss:0.36633
# [91]	validation_0-logloss:0.36633
# [92]	validation_0-logloss:0.36635
# [93]	validation_0-logloss:0.36635
# [94]	validation_0-logloss:0.36636
# [95]	validation_0-logloss:0.36636
# [96]	validation_0-logloss:0.36636
# [97]	validation_0-logloss:0.36638
# [98]	validation_0-logloss:0.36641
# [99]	validation_0-logloss:0.36641

# %% [markdown]
# Check best threshold for train

# %%
models_xgb
# Out:
# [XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=700,
#                enable_categorical=True, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=700,
#                enable_categorical=True, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=700,
#                enable_categorical=True, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=700,
#                enable_categorical=True, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...),
#  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=None, device=None, early_stopping_rounds=700,
#                enable_categorical=True, eval_metric=None, feature_types=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, random_state=None, ...)]

# %%
best_score = 0
Valid_set["category"] = Valid_set["category"].astype("category")
for model in models_xgb:
    valid_pred = model.predict_proba(Valid_set.drop(columns=["user_id", "id", "target"]))[:, 1]
    for i in np.arange(0.01, 1.0, 0.01):
        score = f1 = f1_score(Valid_set.target, (valid_pred.data > i).astype(int))
        if score > best_score:
            best_score = score
            proba_split = i
    print('At i =', "%.2f" % proba_split, 'score is : ' "%.5f" % best_score)
# Out:
# At i = 0.24 score is : 0.59800
# At i = 0.25 score is : 0.60205
# At i = 0.25 score is : 0.60212
# At i = 0.25 score is : 0.60212
# At i = 0.25 score is : 0.60212

# %% [markdown]
# #### 3. Test dataset creation

# %%
Test = Train.copy()

#increment counter
Test['orders_total'] += 1

#add last purchase
Test['ordered'] = Test['ordered'] + Test['target']

#recalculate including last order
test_total_ordered = Test.groupby('category')['ordered'].sum()
Test['total_ordered'] = Test['category'].map(test_total_ordered)

#recalculate including last order
Test['rating'] = Test['ordered'] / Test['orders_total']

Test = Test.drop('target', axis=1)
Test.head(3)
# Out:
#    user_id category  ordered  orders_total    rating   id  total_ordered
# 0        7        0        1            11  0.090909  7;0          14190
# 1        8        0        1             8  0.125000  8;0          14190
# 2        9        0        1            46  0.021739  9;0          14190

# %%
Test["category"] = Test["category"].astype("category")

# %% [markdown]
# #### 4. Get avg predictions from 5 folds

# %%
predictions = []
for model in models_xgb:
    prediction = model.predict_proba(Test.drop(columns=["user_id", "id"]))[:, 1]
    predictions.append(prediction)
predictions
# Out:
# [array([0.09274558, 0.11000419, 0.02168283, ..., 0.03184012, 0.01927452,
#         0.0177153 ], dtype=float32),
#  array([0.08988574, 0.09912319, 0.02851621, ..., 0.04063403, 0.01823885,
#         0.01707705], dtype=float32),
#  array([0.09152331, 0.10601023, 0.02165207, ..., 0.03695901, 0.01680276,
#         0.01329909], dtype=float32),
#  array([0.09196748, 0.11095194, 0.03244093, ..., 0.04163974, 0.02401349,
#         0.02272913], dtype=float32),
#  array([0.08873425, 0.11024296, 0.02688402, ..., 0.03028618, 0.02109117,
#         0.02043149], dtype=float32)]

# %%
avg_preds = sum(predictions) / 5
train_mean = Train.target.mean()

# %% [markdown]
# #### 5. Optimal probability threshold
# Using a threshold probability level of 0.5, the average value of the predictions is less than the average value in the training set.<br>
# Based on the hypothesis that the total number of all purchases of all customers in one order is approximately equal, the optimal probability threshold value is selecting.

# %%
th = 0.5
test_mean = (avg_preds > th).astype(int).mean()
while test_mean < train_mean:
    th -= 0.001
    test_mean = (avg_preds > th).astype(int).mean()
print('Threshold:', "%.4f" % th)
print('Train mean:', "%.5f" % train_mean)
print('New Test mean:', "%.5f" % test_mean)
th
# Out:
# Threshold: 0.2470
# Train mean: 0.23596
# New Test mean: 0.23609
# 0.24699999999999978

# %% [markdown]
# #### 6. Final predictions and submit

# %%
Test['target'] = (avg_preds > th).astype(int)
submit = pd.merge(sub['id'], Test[['id', 'target']], on='id')
submit.to_csv('submission_baseline_xgb_5_folds_4s.csv', index=False)

# %% [markdown]
# Public F1 score: **0.49153** (#17 place avanturer77) p.s изменил гиперпараметры, но закончились сабмиты и пока не знаю сколько xgboost дает сейчас
